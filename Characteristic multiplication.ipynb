# %%
a, b, c, d, e, f, g, h = var('a, b, c, d, e, f, g, h')

A = Matrix([[1,9],[2,3]])
B = Matrix([[6,2],[4,6]])

E1 = Matrix([[1,0],[0,1]])
E2 = Matrix([[1,0],[0,-1]])
E3 = Matrix([[-1,0],[0,1]])
E4 = Matrix([[-1,0],[0,-1]])

U1 = Matrix([[1,0],[0,1]])
U1I = Matrix([[1,0],[0,1]])

U2 = Matrix([[0,1],[1,0]])
U2I = Matrix([[0,1],[1,0]])

M1E1 = A + (E1*U1*B*U1I*E1)
M1E2 = A + (E2*U1*B*U1I*E2)
M1E3 = A + (E3*U1*B*U1I*E3)
M1E4 = A + (E4*U1*B*U1I*E4)

M2E1 = A + (E1*U2*B*U2I*E1)
M2E2 = A + (E2*U2*B*U2I*E2)
M2E3 = A + (E3*U2*B*U2I*E3)
M2E4 = A + (E4*U2*B*U2I*E4)

print(A.eigenvalues())
print(B.eigenvalues())


CP1E1 = M1E1.charpoly()
CP1E2 = M1E2.charpoly()
CP1E3 = M1E3.charpoly()
CP1E4 = M1E4.charpoly()
CP2E1 = M2E1.charpoly()
CP2E2 = M2E2.charpoly()
CP2E3 = M2E3.charpoly()
CP2E4 = M2E4.charpoly()


print('      ')
print(A.charpoly())
print(B.charpoly())
print('      ')
print(CP1E1)
print(CP1E2)
print(CP1E3)
print(CP1E4)
print(CP2E1)
print(CP2E2)
print(CP2E3)
print(CP2E4)
print('      ')
print((1/8)*(CP1E1 + CP1E2 + CP1E3 + CP1E4 + CP2E1 + CP2E2 + CP2E3 + CP2E4))
# Out:
# [-2.358898943540674?, 6.358898943540674?]
# [3.171572875253810?, 8.82842712474619?]
#
# x^2 - 4*x - 15
# x^2 - 12*x + 28
#
# x^2 - 16*x - 3
# x^2 - 16*x + 77
# x^2 - 16*x + 77
# x^2 - 16*x - 3
# x^2 - 16*x + 11
# x^2 - 16*x + 63
# x^2 - 16*x + 63
# x^2 - 16*x + 11
#
# x^2 - 16*x + 37

# %%
a, b, c, d, e, f, g, h = var('a, b, c, d, e, f, g, h')

A = Matrix([[a,b],[c,d]])
B = Matrix([[e,f],[g,h]])

E1 = Matrix([[1,0],[0,1]])
E2 = Matrix([[1,0],[0,-1]])
E3 = Matrix([[-1,0],[0,1]])
E4 = Matrix([[-1,0],[0,-1]])

U1 = Matrix([[1,0],[0,1]])
U1I = Matrix([[1,0],[0,1]])

U2 = Matrix([[0,1],[1,0]])
U2I = Matrix([[0,1],[1,0]])

M1E1 = A*E1*U1*B*U1I*E1
M1E2 = A*E2*U1*B*U1I*E2
M1E3 = A*E3*U1*B*U1I*E3
M1E4 = A*E4*U1*B*U1I*E4

M2E1 = A*E1*U2*B*U2I*E1
M2E2 = A*E2*U2*B*U2I*E2
M2E3 = A*E3*U2*B*U2I*E3
M2E4 = A*E4*U2*B*U2I*E4

print(A.eigenvalues())
print(B.eigenvalues())


CP1E1 = M1E1.charpoly()
CP1E2 = M1E2.charpoly()
CP1E3 = M1E3.charpoly()
CP1E4 = M1E4.charpoly()
CP2E1 = M2E1.charpoly()
CP2E2 = M2E2.charpoly()
CP2E3 = M2E3.charpoly()
CP2E4 = M2E4.charpoly()


print('      ')
print(A.charpoly())
print(B.charpoly())
print('      ')
print(CP1E1)
print(CP1E2)
print(CP1E3)
print(CP1E4)
print(CP2E1)
print(CP2E2)
print(CP2E3)
print(CP2E4)
print('      ')
print((1/8)*(CP1E1 + CP1E2 + CP1E3 + CP1E4 + CP2E1 + CP2E2 + CP2E3 + CP2E4))
# Out:
# [1/2*a + 1/2*d - 1/2*sqrt(a^2 + 4*b*c - 2*a*d + d^2), 1/2*a + 1/2*d + 1/2*sqrt(a^2 + 4*b*c - 2*a*d + d^2)]
# [1/2*e + 1/2*h - 1/2*sqrt(e^2 + 4*f*g - 2*e*h + h^2), 1/2*e + 1/2*h + 1/2*sqrt(e^2 + 4*f*g - 2*e*h + h^2)]
#
# x^2 + (-a - d)*x - b*c + a*d
# x^2 + (-e - h)*x - f*g + e*h
#
# x^2 + (-a*e - c*f - b*g - d*h)*x + b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h
# x^2 + (-a*e + c*f + b*g - d*h)*x + b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h
# x^2 + (-a*e + c*f + b*g - d*h)*x + b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h
# x^2 + (-a*e - c*f - b*g - d*h)*x + b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h
# x^2 + (-d*e - b*f - c*g - a*h)*x + b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h
# x^2 + (-d*e + b*f + c*g - a*h)*x + b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h
# x^2 + (-d*e + b*f + c*g - a*h)*x + b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h
# x^2 + (-d*e - b*f - c*g - a*h)*x + b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h
#
# x^2 + (-1/2*a*e - 1/2*d*e - 1/2*a*h - 1/2*d*h)*x + b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h

# %%
A = Matrix([[1,2,1],[3,1,1],[1,1,1]])
B = Matrix([[1,5,1],[3,1,6],[3,6,2]])

E1 = Matrix([[1,0,0],[0,1,0],[0,0,1]])
E2 = Matrix([[-1,0,0],[0,1,0],[0,0,1]])
E3 = Matrix([[1,0,0],[0,-1,0],[0,0,1]])
E4 = Matrix([[1,0,0],[0,1,0],[0,0,-1]])
E5 = Matrix([[-1,0,0],[0,-1,0],[0,0,1]])
E6 = Matrix([[-1,0,0],[0,1,0],[0,0,-1]])
E7 = Matrix([[1,0,0],[0,-1,0],[0,0,-1]])
E8 = Matrix([[-1,0,0],[0,-1,0],[0,0,-1]])


U1 = Matrix([[1,0,0],[0,1,0],[0,0,1]])
U1I = Matrix([[1,0,0],[0,1,0],[0,0,1]])

U2 = Matrix([[1,0,0],[0,0,1],[0,1,0]])
U2I = Matrix([[1,0,0],[0,0,1],[0,1,0]])

U3 = Matrix([[0,1,0],[1,0,0],[0,0,1]])
U3I = Matrix([[0,1,0],[1,0,0],[0,0,1]])

U4 = Matrix([[0,1,0],[0,0,1],[1,0,0]])
U4I = Matrix([[0,0,1],[1,0,0],[0,1,0]])

U5 = Matrix([[0,0,1],[1,0,0],[0,1,0]])
U5I = Matrix([[0,1,0],[0,0,1],[1,0,0]])

U6 = Matrix([[0,0,1],[0,1,0],[1,0,0]])
U6I = Matrix([[0,0,1],[0,1,0],[1,0,0]])


M1E1 = A + (E1*U1*B*U1I*E1)
M1E2 = A + (E2*U1*B*U1I*E2)
M1E3 = A + (E3*U1*B*U1I*E3)
M1E4 = A + (E4*U1*B*U1I*E4)
M1E5 = A + (E5*U1*B*U1I*E5)
M1E6 = A + (E6*U1*B*U1I*E6)
M1E7 = A + (E7*U1*B*U1I*E7)
M1E8 = A + (E8*U1*B*U1I*E8)

M2E1 = A + (E1*U2*B*U2I*E1)
M2E2 = A + (E2*U2*B*U2I*E2)
M2E3 = A + (E3*U2*B*U2I*E3)
M2E4 = A + (E4*U2*B*U2I*E4)
M2E5 = A + (E5*U2*B*U2I*E5)
M2E6 = A + (E6*U2*B*U2I*E6)
M2E7 = A + (E7*U2*B*U2I*E7)
M2E8 = A + (E8*U2*B*U2I*E8)

M3E1 = A + (E1*U3*B*U3I*E1)
M3E2 = A + (E2*U3*B*U3I*E2)
M3E3 = A + (E3*U3*B*U3I*E3)
M3E4 = A + (E4*U3*B*U3I*E4)
M3E5 = A + (E5*U3*B*U3I*E5)
M3E6 = A + (E6*U3*B*U3I*E6)
M3E7 = A + (E7*U3*B*U3I*E7)
M3E8 = A + (E8*U3*B*U3I*E8)

M4E1 = A + (E1*U4*B*U4I*E1)
M4E2 = A + (E2*U4*B*U4I*E2)
M4E3 = A + (E3*U4*B*U4I*E3)
M4E4 = A + (E4*U4*B*U4I*E4)
M4E5 = A + (E5*U4*B*U4I*E5)
M4E6 = A + (E6*U4*B*U4I*E6)
M4E7 = A + (E7*U4*B*U4I*E7)
M4E8 = A + (E8*U4*B*U4I*E8)

M5E1 = A + (E1*U5*B*U5I*E1)
M5E2 = A + (E2*U5*B*U5I*E2)
M5E3 = A + (E3*U5*B*U5I*E3)
M5E4 = A + (E4*U5*B*U5I*E4)
M5E5 = A + (E5*U5*B*U5I*E5)
M5E6 = A + (E6*U5*B*U5I*E6)
M5E7 = A + (E7*U5*B*U5I*E7)
M5E8 = A + (E8*U5*B*U5I*E8)

M6E1 = A + (E1*U6*B*U6I*E1)
M6E2 = A + (E2*U6*B*U6I*E2)
M6E3 = A + (E3*U6*B*U6I*E3)
M6E4 = A + (E4*U6*B*U6I*E4)
M6E5 = A + (E5*U6*B*U6I*E5)
M6E6 = A + (E6*U6*B*U6I*E6)
M6E7 = A + (E7*U6*B*U6I*E7)
M6E8 = A + (E8*U6*B*U6I*E8)


print(A.eigenvalues())
print(B.eigenvalues())


CP1E1 = M1E1.charpoly()
CP1E2 = M1E2.charpoly()
CP1E3 = M1E3.charpoly()
CP1E4 = M1E4.charpoly()
CP1E5 = M1E5.charpoly()
CP1E6 = M1E6.charpoly()
CP1E7 = M1E7.charpoly()
CP1E8 = M1E8.charpoly()
CP2E1 = M2E1.charpoly()
CP2E2 = M2E2.charpoly()
CP2E3 = M2E3.charpoly()
CP2E4 = M2E4.charpoly()
CP2E5 = M2E5.charpoly()
CP2E6 = M2E6.charpoly()
CP2E7 = M2E7.charpoly()
CP2E8 = M2E8.charpoly()
CP3E1 = M3E1.charpoly()
CP3E2 = M3E2.charpoly()
CP3E3 = M3E3.charpoly()
CP3E4 = M3E4.charpoly()
CP3E5 = M3E5.charpoly()
CP3E6 = M3E6.charpoly()
CP3E7 = M3E7.charpoly()
CP3E8 = M3E8.charpoly()
CP4E1 = M4E1.charpoly()
CP4E2 = M4E2.charpoly()
CP4E3 = M4E3.charpoly()
CP4E4 = M4E4.charpoly()
CP4E5 = M4E5.charpoly()
CP4E6 = M4E6.charpoly()
CP4E7 = M4E7.charpoly()
CP4E8 = M4E8.charpoly()
CP5E1 = M5E1.charpoly()
CP5E2 = M5E2.charpoly()
CP5E3 = M5E3.charpoly()
CP5E4 = M5E4.charpoly()
CP5E5 = M5E5.charpoly()
CP5E6 = M5E6.charpoly()
CP5E7 = M5E7.charpoly()
CP5E8 = M5E8.charpoly()
CP6E1 = M6E1.charpoly()
CP6E2 = M6E2.charpoly()
CP6E3 = M6E3.charpoly()
CP6E4 = M6E4.charpoly()
CP6E5 = M6E5.charpoly()
CP6E6 = M6E6.charpoly()
CP6E7 = M6E7.charpoly()
CP6E8 = M6E8.charpoly()



print('      ')
print(A.charpoly())
print(B.charpoly())
print('      ')
print((1/48)*(CP1E1 +CP1E2 +CP1E3 +CP1E4 +CP1E5 +CP1E6 +CP1E7 +CP1E8 + CP2E1 + CP2E2 + CP2E3 + CP2E4 + CP2E5 + CP2E6 + CP2E7 + CP2E8 +CP3E1 +CP3E2+CP3E3+CP3E4+CP3E5+CP3E6+CP3E7+CP3E8+ CP4E1 +CP4E2 +CP4E3 +CP4E4 +CP4E5 +CP4E6 +CP4E7 +CP4E8 + CP5E1 +CP5E2 +CP5E3 +CP5E4 +CP5E5 +CP5E6 +CP5E7 +CP5E8 + CP6E1 +CP6E2 +CP6E3 +CP6E4 +CP6E5 +CP6E6 +CP6E7 +CP6E8))
# Out:
# [-1.439311671683875?, 0.3388796858734955?, 4.100431985810379?]
# [-4.646516837335123?, -0.9221564634557456?, 9.56867330079087?]
#
# x^3 - 3*x^2 - 5*x + 2
# x^3 - 4*x^2 - 49*x - 41
#
# x^3 - 7*x^2 - 46*x + 50/3

# %%
A = Matrix([[1,2,3],[2,1,3],[3,2,1]])
B = Matrix([[2,4,3],[6,4,1],[1,3,1]])

E1 = Matrix([[1,0,0],[0,1,0],[0,0,1]])
E2 = Matrix([[-1,0,0],[0,1,0],[0,0,1]])
E3 = Matrix([[1,0,0],[0,-1,0],[0,0,1]])
E4 = Matrix([[1,0,0],[0,1,0],[0,0,-1]])
E5 = Matrix([[-1,0,0],[0,-1,0],[0,0,1]])
E6 = Matrix([[-1,0,0],[0,1,0],[0,0,-1]])
E7 = Matrix([[1,0,0],[0,-1,0],[0,0,-1]])
E8 = Matrix([[-1,0,0],[0,-1,0],[0,0,-1]])


U1 = Matrix([[1,0,0],[0,1,0],[0,0,1]])
U1I = Matrix([[1,0,0],[0,1,0],[0,0,1]])

U2 = Matrix([[1,0,0],[0,0,1],[0,1,0]])
U2I = Matrix([[1,0,0],[0,0,1],[0,1,0]])

U3 = Matrix([[0,1,0],[1,0,0],[0,0,1]])
U3I = Matrix([[0,1,0],[1,0,0],[0,0,1]])

U4 = Matrix([[0,1,0],[0,0,1],[1,0,0]])
U4I = Matrix([[0,0,1],[1,0,0],[0,1,0]])

U5 = Matrix([[0,0,1],[1,0,0],[0,1,0]])
U5I = Matrix([[0,1,0],[0,0,1],[1,0,0]])

U6 = Matrix([[0,0,1],[0,1,0],[1,0,0]])
U6I = Matrix([[0,0,1],[0,1,0],[1,0,0]])


M1E1 = A*E1*U1*B*U1I*E1
M1E2 = A*E2*U1*B*U1I*E2
M1E3 = A*E3*U1*B*U1I*E3
M1E4 = A*E4*U1*B*U1I*E4
M1E5 = A*E5*U1*B*U1I*E5
M1E6 = A*E6*U1*B*U1I*E6
M1E7 = A*E7*U1*B*U1I*E7
M1E8 = A*E8*U1*B*U1I*E8

M2E1 = A*E1*U2*B*U2I*E1
M2E2 = A*E2*U2*B*U2I*E2
M2E3 = A*E3*U2*B*U2I*E3
M2E4 = A*E4*U2*B*U2I*E4
M2E5 = A*E5*U2*B*U2I*E5
M2E6 = A*E6*U2*B*U2I*E6
M2E7 = A*E7*U2*B*U2I*E7
M2E8 = A*E8*U2*B*U2I*E8

M3E1 = A*E1*U3*B*U3I*E1
M3E2 = A*E2*U3*B*U3I*E2
M3E3 = A*E3*U3*B*U3I*E3
M3E4 = A*E4*U3*B*U3I*E4
M3E5 = A*E5*U3*B*U3I*E5
M3E6 = A*E6*U3*B*U3I*E6
M3E7 = A*E7*U3*B*U3I*E7
M3E8 = A*E8*U3*B*U3I*E8

M4E1 = A*E1*U4*B*U4I*E1
M4E2 = A*E2*U4*B*U4I*E2
M4E3 = A*E3*U4*B*U4I*E3
M4E4 = A*E4*U4*B*U4I*E4
M4E5 = A*E5*U4*B*U4I*E5
M4E6 = A*E6*U4*B*U4I*E6
M4E7 = A*E7*U4*B*U4I*E7
M4E8 = A*E8*U4*B*U4I*E8

M5E1 = A*E1*U5*B*U5I*E1
M5E2 = A*E2*U5*B*U5I*E2
M5E3 = A*E3*U5*B*U5I*E3
M5E4 = A*E4*U5*B*U5I*E4
M5E5 = A*E5*U5*B*U5I*E5
M5E6 = A*E6*U5*B*U5I*E6
M5E7 = A*E7*U5*B*U5I*E7
M5E8 = A*E8*U5*B*U5I*E8

M6E1 = A*E1*U6*B*U6I*E1
M6E2 = A*E2*U6*B*U6I*E2
M6E3 = A*E3*U6*B*U6I*E3
M6E4 = A*E4*U6*B*U6I*E4
M6E5 = A*E5*U6*B*U6I*E5
M6E6 = A*E6*U6*B*U6I*E6
M6E7 = A*E7*U6*B*U6I*E7
M6E8 = A*E8*U6*B*U6I*E8


print(A.eigenvalues())
print(B.eigenvalues())


CP1E1 = M1E1.charpoly()
CP1E2 = M1E2.charpoly()
CP1E3 = M1E3.charpoly()
CP1E4 = M1E4.charpoly()
CP1E5 = M1E5.charpoly()
CP1E6 = M1E6.charpoly()
CP1E7 = M1E7.charpoly()
CP1E8 = M1E8.charpoly()
CP2E1 = M2E1.charpoly()
CP2E2 = M2E2.charpoly()
CP2E3 = M2E3.charpoly()
CP2E4 = M2E4.charpoly()
CP2E5 = M2E5.charpoly()
CP2E6 = M2E6.charpoly()
CP2E7 = M2E7.charpoly()
CP2E8 = M2E8.charpoly()
CP3E1 = M3E1.charpoly()
CP3E2 = M3E2.charpoly()
CP3E3 = M3E3.charpoly()
CP3E4 = M3E4.charpoly()
CP3E5 = M3E5.charpoly()
CP3E6 = M3E6.charpoly()
CP3E7 = M3E7.charpoly()
CP3E8 = M3E8.charpoly()
CP4E1 = M4E1.charpoly()
CP4E2 = M4E2.charpoly()
CP4E3 = M4E3.charpoly()
CP4E4 = M4E4.charpoly()
CP4E5 = M4E5.charpoly()
CP4E6 = M4E6.charpoly()
CP4E7 = M4E7.charpoly()
CP4E8 = M4E8.charpoly()
CP5E1 = M5E1.charpoly()
CP5E2 = M5E2.charpoly()
CP5E3 = M5E3.charpoly()
CP5E4 = M5E4.charpoly()
CP5E5 = M5E5.charpoly()
CP5E6 = M5E6.charpoly()
CP5E7 = M5E7.charpoly()
CP5E8 = M5E8.charpoly()
CP6E1 = M6E1.charpoly()
CP6E2 = M6E2.charpoly()
CP6E3 = M6E3.charpoly()
CP6E4 = M6E4.charpoly()
CP6E5 = M6E5.charpoly()
CP6E6 = M6E6.charpoly()
CP6E7 = M6E7.charpoly()
CP6E8 = M6E8.charpoly()



print('      ')
print(A.charpoly())
print(B.charpoly())
print('      ')
print((1/48)*(CP1E1 +CP1E2 +CP1E3 +CP1E4 +CP1E5 +CP1E6 +CP1E7 +CP1E8 + CP2E1 + CP2E2 + CP2E3 + CP2E4 + CP2E5 + CP2E6 + CP2E7 + CP2E8 +CP3E1 +CP3E2+CP3E3+CP3E4+CP3E5+CP3E6+CP3E7+CP3E8+ CP4E1 +CP4E2 +CP4E3 +CP4E4 +CP4E5 +CP4E6 +CP4E7 +CP4E8 + CP5E1 +CP5E2 +CP5E3 +CP5E4 +CP5E5 +CP5E6 +CP5E7 +CP5E8 + CP6E1 +CP6E2 +CP6E3 +CP6E4 +CP6E5 +CP6E6 +CP6E7 +CP6E8))
# Out:
# [6, -1, -2]
# [9.05872112968389?, -1.029360564841942? - 1.260871692577146?*I, -1.029360564841942? + 1.260871692577146?*I]
#
# x^3 - 3*x^2 - 16*x - 12
# x^3 - 7*x^2 - 16*x - 24
#
# x^3 - 7*x^2 + 256/3*x - 288

# %%
from itertools import permutations, product


def get_matrix_input(size):
    matrix_input = []
    letters = 'abcdefghijklmnopqrstuvwxyz'

    for i in range(size):
        row_input = input(f"Enter elements for row {i + 1} separated by space, for complex put (Re,Im) and variables a-z then aa-zz: ")
        row_elements = []
        for element in row_input.split():
            if element in letters:
                row_elements.append(var(element))
            else:
                if element.startswith('(') and element.endswith(')'):
                    real_imag = element[1:-1].split(',')
                    if len(real_imag) == 2:
                        real_part = int(real_imag[0])
                        imag_part = int(real_imag[1])
                        row_elements.append(complex(real_part, imag_part))
                    else:
                        row_elements.append(element)
                else:
                    try:
                        row_elements.append(int(element))
                    except ValueError:
                        row_elements.append(element)
        matrix_input.append(row_elements)
    return matrix_input

def calculate_characteristic_polynomial(matrix_list):
    λ = var('λ')
    M = matrix(SR, matrix_list)  # Directly convert the list to a matrix
    
    # Calculate the determinant of (M - xI)
    char_poly = (λ * identity_matrix(M.nrows()) - M).determinant().expand()
    
    return char_poly

def calculate_corresponding_matrix(matrix_values):
    x = var('x')
    M = matrix(SR, matrix_values)  # Directly convert the list to a matrix
    return M   

def generate_permutation_matrices(size):
    P_matrices = []
    permutations_set = set(permutations(range(size)))
    for perm in permutations_set:
        P_list = [[int(i == j) for i in perm] for j in range(size)]
        P = matrix(SR, P_list)
        P_matrices.append(P)
    return P_matrices

def generate_diagonal_variations(size):
    variations = []
    for i in range(2**size):
        variation = [1 if i & (1 << j) else -1 for j in range(size)]
        variations.append(variation)
    E_matrices = [diagonal_matrix(variation) for variation in variations]
    return E_matrices



def main():
    size = int(input("Enter matrix size: "))

    print("Enter elements for the first matrix:")
    A = get_matrix_input(size)
    char_poly_A = calculate_characteristic_polynomial(A)
    AM = calculate_corresponding_matrix(A)
    print(AM)

    print("\nCharacteristic Polynomial of Matrix A:")
    print(char_poly_A)

    print("\nEnter elements for the second matrix:")
    B = get_matrix_input(size)
    char_poly_B = calculate_characteristic_polynomial(B)
    BM = calculate_corresponding_matrix(B)
    print(BM)

    print("\nCharacteristic Polynomial of Matrix B:")
    print(char_poly_B)

    # Generate permutation matrices P
    P_variations = generate_permutation_matrices(size)
    PM = []
    print("\nPermutation Matrices P:")
    for i, P in enumerate(P_variations, 1):
        PM.append(P)
        print(f"P{i}:")
        print(P)

    # Generate diagonal matrix variations E
    E_matrices = generate_diagonal_variations(size)
    print("\nDiagonal Matrix Variations E:")
    for i, E in enumerate(E_matrices, 1):
        print(f"E{i}:")
        print(E)

    
    operation = input("\nEnter 'addition' or 'multiplication': ")

    if operation == 'addition':
        print('\nusing formula: A + (P * E * B * E * P^-1):')
            # Calculate all the characteristic polynomials for variations
        variations_char_polys = []
        variations_matrices = []  # Store matrices for the final sum
        for P in P_variations:
            P_inverse = P.inverse()
            for E in E_matrices:
                Madd_variation =AM + (P * E * BM * E * P_inverse)
                char_poly_Madd_variation = calculate_characteristic_polynomial(Madd_variation)
                variations_char_polys.append(char_poly_Madd_variation)
                variations_matrices.append(Madd_variation)
        total_char_poly = sum(variations_char_polys)
    elif operation == 'multiplication':
        print('\nusing formula: A * P * E * B * E * P^-1:')
            # Calculate all the characteristic polynomials for variations
        variations_char_polys = []
        variations_matrices = []  # Store matrices for the final sum
        for P in P_variations:
            P_inverse = P.inverse()
            for E in E_matrices:
                Mult_variation =AM * P * E * BM * E * P_inverse
                char_poly_Mult_variation = calculate_characteristic_polynomial(Mult_variation)
                variations_char_polys.append(char_poly_Mult_variation)
                variations_matrices.append(Mult_variation)
        total_char_poly = sum(variations_char_polys)
    else:
        print("Invalid operation. Please enter 'addition' or 'multiplication'.")

    # Print all matrices used for the final sum
    print("\nMatrix characteristic polynomials used for the final sum:")
    for matrix_characters in variations_char_polys:
        print(matrix_characters)

    print("\nSum of New Characteristic Polynomials:")
    print(total_char_poly)

        # Sum all the characteristic polynomials for variations
    total_variations_char_poly = ((sum(variations_char_polys))/(factorial(size) * (2 ** size)))


    print("\nSum of Characteristic Polynomials for Variations:")
    print(total_variations_char_poly)


if __name__ == "__main__":
    main()
# Out:
# Enter elements for the first matrix:
# [a b]
# [c d]
#
# Characteristic Polynomial of Matrix A:
# -b*c + a*d - a*λ - d*λ + λ^2
#
# Enter elements for the second matrix:
# [e f]
# [g h]
#
# Characteristic Polynomial of Matrix B:
# -f*g + e*h - e*λ - h*λ + λ^2
#
# Permutation Matrices P:
# P1:
# [1 0]
# [0 1]
# P2:
# [0 1]
# [1 0]
#
# Diagonal Matrix Variations E:
# E1:
# [-1  0]
# [ 0 -1]
# E2:
# [ 1  0]
# [ 0 -1]
# E3:
# [-1  0]
# [ 0  1]
# E4:
# [1 0]
# [0 1]
#
# using formula: A * P * E * B * E * P^-1:
#
# Matrix characteristic polynomials used for the final sum:
# b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h - a*e*λ - c*f*λ - b*g*λ - d*h*λ + λ^2
# b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h - a*e*λ + c*f*λ + b*g*λ - d*h*λ + λ^2
# b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h - a*e*λ + c*f*λ + b*g*λ - d*h*λ + λ^2
# b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h - a*e*λ - c*f*λ - b*g*λ - d*h*λ + λ^2
# b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h - d*e*λ - b*f*λ - c*g*λ - a*h*λ + λ^2
# b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h - d*e*λ + b*f*λ + c*g*λ - a*h*λ + λ^2
# b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h - d*e*λ + b*f*λ + c*g*λ - a*h*λ + λ^2
# b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h - d*e*λ - b*f*λ - c*g*λ - a*h*λ + λ^2
#
# Sum of New Characteristic Polynomials:
# 8*b*c*f*g - 8*a*d*f*g - 8*b*c*e*h + 8*a*d*e*h - 4*a*e*λ - 4*d*e*λ - 4*a*h*λ - 4*d*h*λ + 8*λ^2
#
# Sum of Characteristic Polynomials for Variations:
# b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h - 1/2*a*e*λ - 1/2*d*e*λ - 1/2*a*h*λ - 1/2*d*h*λ + λ^2

# %%
from itertools import permutations, product


def get_matrix_input(size):
    matrix_input = []
    letters = 'abcdefghijklmnopqrstuvwxyz'

    for i in range(size):
        row_input = input(f"Enter elements for row {i + 1} separated by space, for complex put (Re,Im) and variables a-z then aa-zz: ")
        row_elements = []
        for element in row_input.split():
            if element in letters:
                row_elements.append(var(element))
            else:
                if element.startswith('(') and element.endswith(')'):
                    real_imag = element[1:-1].split(',')
                    if len(real_imag) == 2:
                        real_part = int(real_imag[0])
                        imag_part = int(real_imag[1])
                        row_elements.append(complex(real_part, imag_part))
                    else:
                        row_elements.append(element)
                else:
                    try:
                        row_elements.append(int(element))
                    except ValueError:
                        row_elements.append(element)
        matrix_input.append(row_elements)
    return matrix_input

def calculate_characteristic_polynomial(matrix_list):
    λ = var('λ')
    M = matrix(SR, matrix_list)  # Directly convert the list to a matrix
    
    # Calculate the determinant of (M - xI)
    char_poly = (λ * identity_matrix(M.nrows()) - M).determinant().expand()
    
    return char_poly

def calculate_corresponding_matrix(matrix_values):
    x = var('x')
    M = matrix(SR, matrix_values)  # Directly convert the list to a matrix
    return M   

def generate_permutation_matrices(size):
    P_matrices = []
    permutations_set = set(permutations(range(size)))
    for perm in permutations_set:
        P_list = [[int(i == j) for i in perm] for j in range(size)]
        P = matrix(SR, P_list)
        P_matrices.append(P)
    return P_matrices




def main():
    size = int(input("Enter matrix size: "))

    print("Enter elements for the first matrix:")
    A = get_matrix_input(size)
    char_poly_A = calculate_characteristic_polynomial(A)
    AM = calculate_corresponding_matrix(A)
    print(AM)

    print("\nCharacteristic Polynomial of Matrix A:")
    print(char_poly_A)

    print("\nEnter elements for the second matrix:")
    B = get_matrix_input(size)
    char_poly_B = calculate_characteristic_polynomial(B)
    BM = calculate_corresponding_matrix(B)
    print(BM)

    print("\nCharacteristic Polynomial of Matrix B:")
    print(char_poly_B)

    # Generate permutation matrices P
    P_variations = generate_permutation_matrices(size)
    PM = []
    print("\nPermutation Matrices P:")
    for i, P in enumerate(P_variations, 1):
        PM.append(P)
        print(f"P{i}:")
        print(P)


    
    operation = input("\nEnter 'addition' or 'multiplication': ")

    if operation == 'addition':
        print('\nusing formula: A + (P * B * P^-1):')
            # Calculate all the characteristic polynomials for variations
        variations_char_polys = []
        variations_matrices = []  # Store matrices for the final sum
        for P in P_variations:
            P_inverse = P.inverse()
            Madd_variation =AM + (P * BM * P_inverse)
            char_poly_Madd_variation = calculate_characteristic_polynomial(Madd_variation)
            variations_char_polys.append(char_poly_Madd_variation)
            variations_matrices.append(Madd_variation)
        total_char_poly = sum(variations_char_polys)
    elif operation == 'multiplication':
        print('\nusing formula: A * P * B * P^-1:')
            # Calculate all the characteristic polynomials for variations
        variations_char_polys = []
        variations_matrices = []  # Store matrices for the final sum
        for P in P_variations:
            P_inverse = P.inverse()
            Mult_variation =AM * P * BM * P_inverse
            char_poly_Mult_variation = calculate_characteristic_polynomial(Mult_variation)
            variations_char_polys.append(char_poly_Mult_variation)
            variations_matrices.append(Mult_variation)
        total_char_poly = sum(variations_char_polys)
    else:
        print("Invalid operation. Please enter 'addition' or 'multiplication'.")

    # Print all matrices used for the final sum
    print("\nMatrix characteristic polynomials used for the final sum:")
    for matrix_characters in variations_char_polys:
        print(matrix_characters)

    print("\nSum of New Characteristic Polynomials:")
    print(total_char_poly)

        # Sum all the characteristic polynomials for variations
    total_variations_char_poly = (sum(variations_char_polys))


    print("\nSum of Characteristic Polynomials for Variations:")
    print(total_variations_char_poly)


if __name__ == "__main__":
    main()
# Out:
# Enter elements for the first matrix:
# [a b]
# [c d]
#
# Characteristic Polynomial of Matrix A:
# -b*c + a*d - a*λ - d*λ + λ^2
#
# Enter elements for the second matrix:
# [e f]
# [g h]
#
# Characteristic Polynomial of Matrix B:
# -f*g + e*h - e*λ - h*λ + λ^2
#
# Permutation Matrices P:
# P1:
# [1 0]
# [0 1]
# P2:
# [0 1]
# [1 0]
#
# using formula: A * P * B * P^-1:
#
# Matrix characteristic polynomials used for the final sum:
# b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h - a*e*λ - c*f*λ - b*g*λ - d*h*λ + λ^2
# b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h - d*e*λ - b*f*λ - c*g*λ - a*h*λ + λ^2
#
# Sum of New Characteristic Polynomials:
# 2*b*c*f*g - 2*a*d*f*g - 2*b*c*e*h + 2*a*d*e*h - a*e*λ - d*e*λ - b*f*λ - c*f*λ - b*g*λ - c*g*λ - a*h*λ - d*h*λ + 2*λ^2
#
# Sum of Characteristic Polynomials for Variations:
# 2*b*c*f*g - 2*a*d*f*g - 2*b*c*e*h + 2*a*d*e*h - a*e*λ - d*e*λ - b*f*λ - c*f*λ - b*g*λ - c*g*λ - a*h*λ - d*h*λ + 2*λ^2

# %%
from itertools import permutations, product


def get_matrix_input(size):
    matrix_input = []
    letters = 'abcdefghijklmnopqrstuvwxyz'

    for i in range(size):
        row_input = input(f"Enter elements for row {i + 1} separated by space, for complex put (Re,Im) and variables a-z then aa-zz: ")
        row_elements = []
        for element in row_input.split():
            if element in letters:
                row_elements.append(var(element))
            else:
                if element.startswith('(') and element.endswith(')'):
                    real_imag = element[1:-1].split(',')
                    if len(real_imag) == 2:
                        real_part = int(real_imag[0])
                        imag_part = int(real_imag[1])
                        row_elements.append(complex(real_part, imag_part))
                    else:
                        row_elements.append(element)
                else:
                    try:
                        row_elements.append(int(element))
                    except ValueError:
                        row_elements.append(element)
        matrix_input.append(row_elements)
    return matrix_input

def calculate_characteristic_polynomial(matrix_list):
    λ = var('λ')
    M = matrix(SR, matrix_list)  # Directly convert the list to a matrix
    
    # Calculate the determinant of (M - xI)
    char_poly = (λ * identity_matrix(M.nrows()) - M).determinant().expand()
    
    return char_poly

def calculate_corresponding_matrix(matrix_values):
    x = var('x')
    M = matrix(SR, matrix_values)  # Directly convert the list to a matrix
    return M   

def generate_permutation_matrices(size):
    P_matrices = []
    permutations_set = set(permutations(range(size)))
    for perm in permutations_set:
        P_list = [[int(i == j) for i in perm] for j in range(size)]
        P = matrix(SR, P_list)
        P_matrices.append(P)
    return P_matrices

def generate_diagonal_variations(size):
    variations = []
    for i in range(2**size):
        variation = [1 if i & (1 << j) else -1 for j in range(size)]
        variations.append(variation)
    E_matrices = [diagonal_matrix(variation) for variation in variations]
    return E_matrices



def main():
    size = int(input("Enter matrix size: "))

    print("Enter elements for the first matrix:")
    A = get_matrix_input(size)
    char_poly_A = calculate_characteristic_polynomial(A)
    AM = calculate_corresponding_matrix(A)
    print(AM)

    print("\nCharacteristic Polynomial of Matrix A:")
    print(char_poly_A)

    print("\nEnter elements for the second matrix:")
    B = get_matrix_input(size)
    char_poly_B = calculate_characteristic_polynomial(B)
    BM = calculate_corresponding_matrix(B)
    print(BM)

    print("\nCharacteristic Polynomial of Matrix B:")
    print(char_poly_B)

    # Generate permutation matrices P
    P_variations = generate_permutation_matrices(size)
    PM = []
    print("\nPermutation Matrices P:")
    for i, P in enumerate(P_variations, 1):
        PM.append(P)
        print(f"P{i}:")
        print(P)

    # Generate diagonal matrix variations E
    E_matrices = generate_diagonal_variations(size)
    print("\nDiagonal Matrix Variations E:")
    for i, E in enumerate(E_matrices, 1):
        print(f"E{i}:")
        print(E)

    
    operation = input("\nEnter 'addition' or 'multiplication': ")

    if operation == 'addition':
        print('\nusing formula: A + (P * E * B * E * P^-1):')
            # Calculate all the characteristic polynomials for variations
        variations_char_polys = []
        variations_matrices = []  # Store matrices for the final sum
        for P in P_variations:
            P_inverse = P.inverse()
            for E in E_matrices:
                Madd_variation =AM + (P * E * BM * E * P_inverse)
                char_poly_Madd_variation = calculate_characteristic_polynomial(Madd_variation)
                variations_char_polys.append(char_poly_Madd_variation)
                variations_matrices.append(Madd_variation)
        total_char_poly = sum(variations_char_polys)
    elif operation == 'multiplication':
        print('\nusing formula: A * P * E * B * E * P^-1:')
            # Calculate all the characteristic polynomials for variations
        variations_char_polys = []
        variations_matrices = []  # Store matrices for the final sum
        for P in P_variations:
            P_inverse = P.inverse()
            for E in E_matrices:
                Mult_variation =AM * P * E * BM * E * P_inverse
                char_poly_Mult_variation = calculate_characteristic_polynomial(Mult_variation)
                variations_char_polys.append(char_poly_Mult_variation)
                variations_matrices.append(Mult_variation)
        total_char_poly = sum(variations_char_polys)
    else:
        print("Invalid operation. Please enter 'addition' or 'multiplication'.")

    # Print all matrices used for the final sum
    print("\nMatrix characteristic polynomials used for the final sum:")
    for matrix_characters in variations_char_polys:
        print(matrix_characters)

    print("\nSum of New Characteristic Polynomials:")
    print(total_char_poly)

        # Sum all the characteristic polynomials for variations
    total_variations_char_poly = ((sum(variations_char_polys))/(factorial(size) * (2 ** size)))


    print("\nSum of Characteristic Polynomials for Variations:")
    print(total_variations_char_poly)


    if operation == 'addition':
        print('\nNow using formula: A + (P * B * P^-1):')
            # Calculate all the characteristic polynomials for variations
        variations_char_polys_1 = []
        variations_matrices_1 = []  # Store matrices for the final sum
        for P in P_variations:
            P_inverse = P.inverse()
            Madd_variation_1 =AM + (P * BM * P_inverse)
            char_poly_Madd_variation_1 = calculate_characteristic_polynomial(Madd_variation_1)
            variations_char_polys_1.append(char_poly_Madd_variation_1)
            variations_matrices_1.append(Madd_variation_1)
        total_char_poly_1 = sum(variations_char_polys_1)
    elif operation == 'multiplication':
        print('\nNow using formula: A * P * B * P^-1:')
            # Calculate all the characteristic polynomials for variations
        variations_char_polys_1 = []
        variations_matrices_1 = []  # Store matrices for the final sum
        for P in P_variations:
            P_inverse = P.inverse()
            Mult_variation_1 =AM * P * BM * P_inverse
            char_poly_Mult_variation_1 = calculate_characteristic_polynomial(Mult_variation_1)
            variations_char_polys_1.append(char_poly_Mult_variation_1)
            variations_matrices_1.append(Mult_variation_1)
        total_char_poly_1 = sum(variations_char_polys_1)
    else:
        print("Invalid operation. Please enter 'addition' or 'multiplication'.")

    # Print all matrices used for the final sum
    print("\nMatrix characteristic polynomials used for the final sum:")
    for matrix_characters in variations_char_polys_1:
        print(matrix_characters)

    print("\nSum of New Characteristic Polynomials:")
    print(total_char_poly_1)

        # Sum all the characteristic polynomials for variations
    total_variations_char_poly_1 = ((sum(variations_char_polys_1))/(factorial(size)))


    print("\nSum of Characteristic Polynomials for Variations:")
    print(total_variations_char_poly_1)

    final_char_poly = total_variations_char_poly - total_variations_char_poly_1

    print("\nDifference of two calculations:")
    print(final_char_poly)

if __name__ == "__main__":
    main()
# Out:
# Enter elements for the first matrix:
# [a b]
# [c d]
#
# Characteristic Polynomial of Matrix A:
# -b*c + a*d - a*λ - d*λ + λ^2
#
# Enter elements for the second matrix:
# [e f]
# [g h]
#
# Characteristic Polynomial of Matrix B:
# -f*g + e*h - e*λ - h*λ + λ^2
#
# Permutation Matrices P:
# P1:
# [1 0]
# [0 1]
# P2:
# [0 1]
# [1 0]
#
# Diagonal Matrix Variations E:
# E1:
# [-1  0]
# [ 0 -1]
# E2:
# [ 1  0]
# [ 0 -1]
# E3:
# [-1  0]
# [ 0  1]
# E4:
# [1 0]
# [0 1]
#
# using formula: A * P * E * B * E * P^-1:
#
# Matrix characteristic polynomials used for the final sum:
# b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h - a*e*λ - c*f*λ - b*g*λ - d*h*λ + λ^2
# b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h - a*e*λ + c*f*λ + b*g*λ - d*h*λ + λ^2
# b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h - a*e*λ + c*f*λ + b*g*λ - d*h*λ + λ^2
# b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h - a*e*λ - c*f*λ - b*g*λ - d*h*λ + λ^2
# b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h - d*e*λ - b*f*λ - c*g*λ - a*h*λ + λ^2
# b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h - d*e*λ + b*f*λ + c*g*λ - a*h*λ + λ^2
# b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h - d*e*λ + b*f*λ + c*g*λ - a*h*λ + λ^2
# b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h - d*e*λ - b*f*λ - c*g*λ - a*h*λ + λ^2
#
# Sum of New Characteristic Polynomials:
# 8*b*c*f*g - 8*a*d*f*g - 8*b*c*e*h + 8*a*d*e*h - 4*a*e*λ - 4*d*e*λ - 4*a*h*λ - 4*d*h*λ + 8*λ^2
#
# Sum of Characteristic Polynomials for Variations:
# b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h - 1/2*a*e*λ - 1/2*d*e*λ - 1/2*a*h*λ - 1/2*d*h*λ + λ^2
#
# Now using formula: A * P * B * P^-1:
#
# Matrix characteristic polynomials used for the final sum:
# b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h - a*e*λ - c*f*λ - b*g*λ - d*h*λ + λ^2
# b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h - d*e*λ - b*f*λ - c*g*λ - a*h*λ + λ^2
#
# Sum of New Characteristic Polynomials:
# 2*b*c*f*g - 2*a*d*f*g - 2*b*c*e*h + 2*a*d*e*h - a*e*λ - d*e*λ - b*f*λ - c*f*λ - b*g*λ - c*g*λ - a*h*λ - d*h*λ + 2*λ^2
#
# Sum of Characteristic Polynomials for Variations:
# b*c*f*g - a*d*f*g - b*c*e*h + a*d*e*h - 1/2*a*e*λ - 1/2*d*e*λ - 1/2*b*f*λ - 1/2*c*f*λ - 1/2*b*g*λ - 1/2*c*g*λ - 1/2*a*h*λ - 1/2*d*h*λ + λ^2
#
# Difference of two calculations:
# 1/2*b*f*λ + 1/2*c*f*λ + 1/2*b*g*λ + 1/2*c*g*λ
